# %% [markdown]
# # Instance Attributes and Instance Methods
# By:<a href='https://www.youtube.com/wonkyCode'>WonkyCode</a>

# %%
class User:
    
    def __init__(self, first, last, age):
        self.first = first
        self.last = last
        self.age = age
        
    def fullName(self):
        return f"{self.first} {self.last}"
    
    def initials(self):
        return f"{self.first[0]}.{self.last[0]}"
    
    def likes(self, thing):
        return f"{self.first} likes {thing}"
    
    def is_senior(self):
        return self.age >= 65
    
    def birthday(self):
        self.age += 1
        return f"Happy {self.age}th Birthday, {self.first}"

# %%
user1 = User("Rohit", "Kumar", 24)
user2 = User("Prasad", "Sana", 35)

# %%
user1.likes("cricket")
# Out:
# 'Rohit likes cricket'

# %%
user2.is_senior()
# Out:
# False

# %%
user1.age
# Out:
# 24

# %%
user1.birthday()

# %%
User.birthday()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-e41fc30420e8> in <module>
# ----> 1 User.birthday()
#
# TypeError: birthday() missing 1 required positional argument: 'self'
